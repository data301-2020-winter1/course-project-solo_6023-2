# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
from script import project_functions
url="../data/raw/13100762.csv"
df = project_functions.load_and_process(url)

df.to_csv("../data/processed/13100762_cleaned.csv", index = False)
df
# Out:
#        REF_DATE                        GEO         Sex  \
# 0          2011  Newfoundland and Labrador  Both sexes
# 1          2011  Newfoundland and Labrador  Both sexes
# 2          2011  Newfoundland and Labrador  Both sexes
# 3          2011  Newfoundland and Labrador  Both sexes
# 4          2011  Newfoundland and Labrador  Both sexes
# ...         ...                        ...         ...
# 36811      2017                    Nunavut     Females
# 36812      2017                    Nunavut     Females
# 36813      2017                    Nunavut     Females
# 36814      2017                    Nunavut     Females
# 36815      2017                    Nunavut     Females
#
#                                          Characteristics      Primary_Types  \
# 0                           Total number of cancer cases  Colon and rectum
# 1                                  Cancer incidence rate  Colon and rectum
# ...

# %%
df_mf = df.loc[~df.Sex.str.contains("Both sexes")]
plt.figure(figsize=(25,8))

ax=sns.catplot(data=df_mf, x="REF_DATE", kind="countic", hue="Sex", palette="pastel")

plt.title("No. of Cancer Cases from 2011-17", loc='center',  fontdict={'fontsize': 20})
ax.set_xticklabels(rotation=30, fontdict={'fontsize': 12})

plt.xlabel("", loc='center',  fontdict={'fontsize': 15})ic
plt.ylabel("No. of Cases", loc='center',  fontdict={'fontsize': 15})
plt.savefig("../images/Cancer Cases 2011-17")

# %% [markdown]
# ## Observations for Graph Above
#
# ##### **No. of Cases from 2011-17**
# - This graph shows us that the number of different types of cancer cases in females are more than in males.
# - The number of cases have remained more or less steady in both the sexes.

# %%
plt.figure(figsize=(25,8))

ax=sns.countplot(data=df, hue="Primary_Types", x="GEO", palette="viridis")
plt.legend(bbox_to_anchor=(1,0.75), borderaxespad=2)
plt.title("Types of Cancer in each Province (except Quebec)", loc='center',  fontdict={'fontsize': 25})
ax.set_xticklabels(ax.get_xticklabels(), rotation=20, fontdict={'fontsize': 12})
ax.set_ylabel("No. of Cases", loc='center',  fontdict={'fontsize': 20})
ax.set_xlabel("Provinces", loc='center',  fontdict={'fontsize': 20})
sns.despine()

plt.savefig("../images/Cancer Cases by Province")

# %% [markdown]
# ## Observations for Graph Above
#
#
# ##### **Types of Cancer in each Province**
#  - Colon Cancer remains predominant type of cancer throughout Canada.
#
#  - Yukon and Nunavut have lesser number of Prostate Cancer cases compared to Cervical Cancer even though the population of males is higher in both these territories. This could be attributed to success of various awareness programs in these territories.
#
#  - Even though Ontario has much higher population than Saskatchewan the number of cancer cases are comparable which is a major cause of concern. This would mean that more detailed analysis needs to be done to identify the causes and mitigate them at an early stage. My speculation is that this trend has been observed because the median age in Saskatchewan is higher than in Ontario. Also probably due to extensive exposure to pesticides since Saskatchewan is predominantly an agrarian province.

# %%
df2 = df.loc[~df.Stage.str.contains("Stage not available")].loc[~df.Stage.str.contains("Stage unknown")].loc[~df.Stage.str.contains("All stages combined")]

plt.figure(figsize=(20,8))
ax=sns.countplot(data=df2, hue="Primary_Types", x="Stage", palette="icefire")

plt.legend(bbox_to_anchor=(1,0.75), borderaxespad=2)
plt.title("Various stages of cancer according to Cancer type", loc='center',  fontdict={'fontsize': 20})
ax.set_ylabel("No. of Cases", loc='center',  fontdict={'fontsize': 15})
ax.set_xlabel("Stages", loc='center',  fontdict={'fontsize': 15})
sns.despine()

plt.savefig("../images/Cancer Types in different stages")

# %% [markdown]
# ## Observations for Graph Above
#
#
# ##### **Types of Cancer in each Province**
# - When looking at Lung and bronchus cancer, Cervical Cancer, and Prostate Cancer over different stages, it clearly tells us that many cases are intercepted in the latter stages. This is a major cause of concern which implies that early detection systems are not that effective.  This further implies that we need to focus our research and develop technologies to better understand and itercept these cancer types before they become fatal.
